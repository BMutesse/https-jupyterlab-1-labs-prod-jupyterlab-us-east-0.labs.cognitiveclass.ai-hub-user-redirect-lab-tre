# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# This is a notebook that summarises Data Science Tools and Ecosystem

# %% [markdown]
# **Objectives:**
# - To list some of the popular languages used by Data Scientists,
# - List some of the commonly used Data Science libraries and,
# - Perform simple arithmetics in Jupyter notebook.

# %% [markdown]
# Some of the popular languages Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL

# %% [markdown]
# Some of the commonly used Data Science libraries are:
# 1. Pandas
# 2. TensorFlow
# 3. NumPy
# 4. SciPy
# 5. PyTorch
# 6. Keras

# %% [markdown]
# |  Data Science Tools     |
# |-------------------------|
# |GitHub                   |
# |Jupyter notebook         |
# |RStudio                  |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
print ("This is a simple expression to add and multiply integers")
(3*4)+5
# Out:
# This is a simple expression to add and multiply integers
# 17

# %%
print ("This will convert 200 minutes to hours by dividing by 60") 
200/60
# Out:
# This will convert 200 minutes to hours by dividing by 60
# 3.3333333333333335

# %% [markdown]
# **Author**
#
# Bongane Mutesse
